# %% [markdown]
# Popularity Based Filtering

# %%
import pandas as pd

# %%
movie = pd.read_csv('movies.csv')
credit = pd.read_csv('credits.csv')
rating = pd.read_csv('ratings.csv')

# %%
movie.vote_average
# Out:
# 0       7.2
# 1       6.9
# 2       6.3
# 3       7.6
# 4       6.1
#        ...
# 4798    6.6
# 4799    5.9
# 4800    7.0
# 4801    5.7
# 4802    6.3
# Name: vote_average, Length: 4803, dtype: float64

# %%
credit.title.head(10)
# Out:
# 0                                      Avatar
# 1    Pirates of the Caribbean: At World's End
# 2                                     Spectre
# 3                       The Dark Knight Rises
# 4                                 John Carter
# 5                                Spider-Man 3
# 6                                     Tangled
# 7                     Avengers: Age of Ultron
# 8      Harry Potter and the Half-Blood Prince
# 9          Batman v Superman: Dawn of Justice
# Name: title, dtype: object

# %%
rating.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205
# 5       1     1263     2.0  1260759151
# 6       1     1287     2.0  1260759187
# 7       1     1293     2.0  1260759148
# 8       1     1339     3.5  1260759125
# 9       1     1343     2.0  1260759131

# %% [markdown]
# Calculate the weighted rating

# %% [markdown]
# WR = (v ÷ (v+m)) × R + (m ÷ (v+m)) × C
#
# R = average for the movie (mean) = (Rating)\n
#
# v = number of votes for the movie = (votes)
#
# m = minimum votes required to be listed in the Top 250 (currently 25000)
#
# C Average rating across all the movies

# %%
m = movie['vote_count'].quantile(0.9)
m
# Out:
# np.float64(1838.4000000000015)

# %%
C = movie.vote_average.mean()
C
# Out:
# np.float64(6.092171559442016)

# %%
movie_filtered = movie.copy().loc[movie.vote_count > m]

# %%
movie_filtered
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4291    1200000  [{"id": 27, "name": "Horror"}, {"id": 9648, "n...
# 4300    1200000  [{"id": 80, "name": "Crime"}, {"id": 53, "name...
# 4302    1200000                    [{"id": 37, "name": "Western"}]
# 4337    1300000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 4602     350000                      [{"id": 18, "name": "Drama"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
def weighted_rating(df, m=m,C=C):
    R = df['vote_average']
    v = df['vote_count'] 
    WR = (v / (v+m)) * R + (m / (v+m)) * C
    return WR

# %%
movie_filtered["weighted_rating"] = movie.apply(weighted_rating, axis = 1)

# %%
movie_filtered.weighted_rating
# Out:
# 0       7.050669
# 1       6.665696
# 2       6.239396
# 3       7.346721
# 4       6.096368
#           ...
# 4291    6.693677
# 4300    7.366378
# 4302    7.210428
# 4337    7.198026
# 4602    7.210563
# Name: weighted_rating, Length: 481, dtype: float64

# %%
movie_filtered.sort_values('weighted_rating', ascending=False)[['title', 'weighted_rating']]
# Out:
#                              title  weighted_rating
# 1881      The Shawshank Redemption         8.059258
# 662                     Fight Club         7.939256
# 65                 The Dark Knight         7.920020
# 3232                  Pulp Fiction         7.904645
# 96                       Inception         7.863239
# ...                            ...              ...
# 41                   Green Lantern         5.521697
# 337         A Good Day to Die Hard         5.507643
# 193                    After Earth         5.459420
# 91    Independence Day: Resurgence         5.406234
# 242                 Fantastic Four         5.155730
#
# [481 rows x 2 columns]
